# %% [markdown]
# # 環境チェック
#
# - 実行できるかの確認
# -

# %%
print("test")
# Out:
# test

# %%
import pymc as pm, arviz as az, numpy as np, japanize_matplotlib
print(pm.__version__)
# Out:
# /Users/nkn4ryu/ghq/github.com/shiryu-nakano/DeepLearning_tutorial/.venv/lib/python3.10/site-packages/arviz/data/base.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 5.7.2
